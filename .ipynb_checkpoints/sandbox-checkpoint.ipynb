# %%
import numpy as np
import pandas as pd
import pypsa

import sys
from pathlib import Path

sys.path.insert(0, str(Path("src")))

from src import network_builder
from src import util
from util import annualized_capex

# %%
data = pd.read_csv("data/clean_data.csv")

# %%
snapshots = data.index
nHours = len(snapshots)

load = pd.DataFrame(index=snapshots)
load["reg1"] = data["load_mw"] * .3
load["reg2"] = data["load_mw"] *  .5
load["reg3"] = data["load_mw"] * .7

solar = pd.DataFrame(index=snapshots)
solar["reg1"] = data["ca_pv_cf"]
solar["reg2"] = data["az_pv_cf"]
solar["reg3"] = data["nv_pv_cf"]

wind = pd.DataFrame(index=snapshots)
wind["reg1"] = data["ca_wind_cf"]
wind["reg2"] = data["pnw_wind_cf"]
wind["reg3"] = data["wy_wind_cf"]

# %%
total_load_mwh = load.sum().sum()
baseline_emissions = total_load_mwh * 0.4
co2_cap = baseline_emissions * 0.05   # for a 95% reduction


ldes_cost_case = "medium"
transmission_friction = "low"
ldes_duration_hours = 24

# %%
n = network_builder.build_network(snapshots, load, wind, solar, co2_cap, ldes_cost_case, transmission_friction, ldes_duration_hours)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 n = network_builder.build_network(snapshots, load, wind, solar, co2_cap, ldes_duration_hours,
#       2                                   ldes_cost_case, transmission_friction)
#
# File ~/Documents/GitHub/esm-capstone/src/network_builder.py:57, in build_network(snapshots, load, wind_cf, solar_cf, co2_cap_tons, ldes_cost_case, transmission_friction, ldes_duration_hours)
#      50 short_storage_capex = annualized_capex(short_storage_capex_per_mw, 15, wacc, 0.02)
#      52 ldes_cost_multipliers = {
#      53     "low": 0.70,
#      54     "medium": 1.00,
#      55     "high": 1.40,
#      56 }
# ---> 57 ldes_mult = ldes_cost_multipliers[ldes_cost_case]
#      58 ldes_capex = annualized_capex(ldes_base_capex_per_mw * ldes_mult, 20, wacc, 0.02)
#      60 # Backup generation
#
# KeyError: 24

# %%
RESOLUTION = 1
n.set_snapshots(n.snapshots[::RESOLUTION])
n.snapshot_weightings.loc[:, :] = RESOLUTION

n.optimize()
# Out:
# /var/folders/t_/32_5y8z906v9c0l8qphz6hx00000gn/T/ipykernel_65735/243138191.py:5: FutureWarning:
#
# The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#
# WARNING:pypsa.consistency:The following buses have carriers which are not defined. Run n.sanitize() to add them. Components with undefined carriers:
# Index(['reg1', 'reg2', 'reg3'], dtype='object', name='name')
# WARNING:pypsa.consistency:Encountered nan's in static data for columns ['max_relative_growth', 'max_growth'] of component 'Carrier'.
# WARNING:pypsa.consistency:The following links have carriers which are not defined. Run n.sanitize() to add them. Components with undefined carriers:
# Index(['tx_reg1_reg2', 'tx_reg1_reg3', 'tx_reg2_reg3'], dtype='object', name='name')
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|████████████████████| 16/16 [00:00<00:00, 116.82it/s]
# Writing continuous variables.: 100%|█████████████| 8/8 [00:00<00:00, 562.71it/s]
# INFO:linopy.io: Writing time: 0.26s
# Running HiGHS 1.13.1 (git hash: n/a): Copyright (c) 2026 under MIT licence terms
# LP linopy-problem-bwhthyjg has 603907 rows; 262578 cols; 1246087 nonzeros
# Coefficient ranges:
#   Matrix  [1e-03, 1e+01]
#   Cost    [1e+02, 2e+05]
#   Bound   [0e+00, 0e+00]
#   RHS     [5e+03, 7e+06]
# WARNING: Problem has some excessively large row bounds
# WARNING:    Consider scaling the    bounds by 1e-1, or setting the user_bound_scale option to -3
# Presolving model
# 327110 rows, 248359 cols, 955071 nonzeros  0s
# Dependent equations search running on 78768 equations with time limit of 1000.00s
# Dependent equations search removed 0 rows and 0 nonzeros in 0.00s (limit = 1000.00s)
#
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 262578 primals, 603907 duals
# Objective: 4.08e+10
# Solver model: available
# Solver message: Optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Link-ext-p-lower, Link-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# Model name          : linopy-problem-bwhthyjg
# Model status        : Optimal
# Simplex   iterations: 339061
# Objective value     :  4.0775698899e+10
# P-D objective error :  1.0936369514e-13
# HiGHS run time      :       1968.74
# ('ok', 'optimal')

# %%
n.generators
# Out:
#               bus control type  p_nom  p_nom_mod  p_nom_extendable  p_nom_min  \
# name
# wind_reg1    reg1   Slack         0.0        0.0              True        0.0
# solar_reg1   reg1      PQ         0.0        0.0              True        0.0
# backup_reg1  reg1      PQ         0.0        0.0              True        0.0
# wind_reg2    reg2   Slack         0.0        0.0              True        0.0
# solar_reg2   reg2      PQ         0.0        0.0              True        0.0
# backup_reg2  reg2      PQ         0.0        0.0              True        0.0
# wind_reg3    reg3   Slack         0.0        0.0              True        0.0
# solar_reg3   reg3      PQ         0.0        0.0              True        0.0
# backup_reg3  reg3      PQ         0.0        0.0              True        0.0
#
#              p_nom_max  p_nom_set  p_min_pu  ...  min_up_time  min_down_time  \
# name                                         ...
# wind_reg1          inf        NaN       0.0  ...            0              0
# solar_reg1         inf        NaN       0.0  ...            0              0
# backup_reg1        inf        NaN       0.0  ...            0              0
# wind_reg2          inf        NaN       0.0  ...            0              0
# solar_reg2         inf        NaN       0.0  ...            0              0
# backup_reg2        inf        NaN       0.0  ...            0              0
# wind_reg3          inf        NaN       0.0  ...            0              0
# solar_reg3         inf        NaN       0.0  ...            0              0
# backup_reg3        inf        NaN       0.0  ...            0              0
#
#              up_time_before  down_time_before  ramp_limit_up  ramp_limit_down  \
# name
# wind_reg1                 1                 0            NaN              NaN
# solar_reg1                1                 0            NaN              NaN
# backup_reg1               1                 0            NaN              NaN
# wind_reg2                 1                 0            NaN              NaN
# solar_reg2                1                 0            NaN              NaN
# backup_reg2               1                 0            NaN              NaN
# wind_reg3                 1                 0            NaN              NaN
# solar_reg3                1                 0            NaN              NaN
# backup_reg3               1                 0            NaN              NaN
#
#              ramp_limit_start_up ramp_limit_shut_down  weight     p_nom_opt
# name
# wind_reg1                    NaN                  NaN     1.0  23806.746212
# solar_reg1                   NaN                  NaN     1.0  18454.991876
# backup_reg1                  NaN                  NaN     1.0  12498.733555
# wind_reg2                    NaN                  NaN     1.0     -0.000000
# solar_reg2                   NaN                  NaN     1.0  22205.710051
# backup_reg2                  NaN                  NaN     1.0  13347.193751
# wind_reg3                    NaN                  NaN     1.0  23537.891242
# solar_reg3                   NaN                  NaN     1.0  17032.035219
# backup_reg3                  NaN                  NaN     1.0  20317.841992
#
# [9 rows x 42 columns]

# %%
n
# Out:
# PyPSA Network 'Unnamed Network'
# -------------------------------
# Components:
#  - Bus: 3
#  - Generator: 9
#  - Load: 3
#  - StorageUnit: 6
# Snapshots: 8752

# %%
n2
# Out:
# PyPSA Network 'Unnamed Network'
# -------------------------------
# Components:
#  - Bus: 3
#  - Generator: 9
#  - Link: 3
#  - StorageUnit: 6
# Snapshots: 8752
