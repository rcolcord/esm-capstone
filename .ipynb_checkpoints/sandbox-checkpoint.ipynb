# %%
import numpy as np
import pandas as pd
import pypsa

import sys
from pathlib import Path

sys.path.insert(0, str(Path("src")))

# %%
from src import visualize_results
import matplotlib.pyplot as plt

# Load and inspect
results = visualize_results.load_core_results("results")
visualize_results.check_columns(results)

summary = visualize_results.make_summary_table(results)
display(summary)
# Out:
# Columns:
# ['backup_capex', 'backup_mw', 'backup_opex', 'battery4h_capex', 'battery4h_mw', 'battery4h_mwh', 'co2_cap_tons', 'cost_reconstruction_error', 'generator_capex_total', 'generator_opex_total', 'ldes_capex', 'ldes_capex_per_mw', 'ldes_duration_hours', 'ldes_mw', 'ldes_mwh', 'objective', 'reconstructed_total_cost', 'renewable_correlation_case', 'scenario_id', 'solar_capex', 'solar_mw', 'solar_opex', 'solver_condition', 'solver_status', 'storage_capex_total', 'system_cost_per_mwh', 'total_capex', 'total_generation_mwh', 'total_load_mwh', 'total_opex', 'transmission_capex', 'transmission_capex_per_mw', 'transmission_capex_total', 'transmission_mw', 'vres_available_mwh', 'vres_curtailment_mwh', 'vres_dispatched_mwh', 'wind_capex', 'wind_mw', 'wind_opex']
#
# Preview:
#          scenario_id renewable_correlation_case  ldes_duration_hours  \
# 0   corr_low_dur_10h                        low                   10
# 1   corr_low_dur_24h                        low                   24
# ...

# %%
fig, axes = visualize_results.plot_tx_vs_ldes_panel(results)
plt.show()

# %%
# Paper figures
visualize_results.set_paper_style()

# Main paper panel
#fig, axes = visualize_results.plot_paper_main_panel(results)
#plt.show()

# Alternative paper panel
#fig, axes = visualize_results.plot_paper_alt_panel(results)
#plt.show()

# Individual useful paper plots
fig, ax = plt.subplots()
visualize_results.plot_system_cost(results, ax=ax)
plt.show()

fig, ax = plt.subplots()
visualize_results.plot_curtailment(results, ax=ax)
plt.show()

fig, ax = plt.subplots()
visualize_results.plot_transmission_build(results, ax=ax)
plt.show()

fig, ax = plt.subplots()
visualize_results.plot_ldes_power(results, ax=ax)
plt.show()

fig, ax = plt.subplots()
visualize_results.plot_ldes_energy(results, ax=ax)
plt.show()

visualize_results.create_paper_figures(results, outdir="figures/paper")


visualize_results.set_slide_style()
visualize_results.create_slide_figures(results, outdir="figures/slides")

"""
fig, ax = plt.subplots()
visualize_results.plot_backup_capacity(results, ax=ax)
plt.show()

fig, ax = plt.subplots(figsize=(8.5, 4.8))
visualize_results.plot_storage_comparison(results, ax=ax)
plt.show()

fig, ax = plt.subplots(figsize=(7, 6))
visualize_results.plot_ldes_vs_transmission(results, ax=ax)
plt.show()

fig, ax = plt.subplots(figsize=(10, 5))
visualize_results.plot_generation_mix_bars(results, ax=ax)
plt.show()

# Optional cost figures
if {
    "generator_capex_total",
    "storage_capex_total",
    "link_capex_total",
    "generator_opex_total",
}.issubset(results.columns):
    fig, ax = plt.subplots(figsize=(10, 5))
    visualize_results.plot_cost_components(results, ax=ax)
    plt.show()

if {"total_capex", "total_opex"}.issubset(results.columns):
    fig, ax = plt.subplots(figsize=(8.5, 4.8))
    visualize_results.plot_capex_vs_opex(results, ax=ax)
    plt.show()

if "cost_reconstruction_error" in results.columns:
    fig, ax = plt.subplots(figsize=(8.5, 4.5))
    visualize_results.plot_cost_reconstruction_error(results, ax=ax)
    plt.show()

# Optional faceted comparison
g = visualize_results.plot_longform_facets(
    results,
    metrics=[
        "system_cost_per_mwh",
        "transmission_mw",
        "ldes_mw",
        "vres_curtailment_mwh",
    ],
    metric_labels={
        "system_cost_per_mwh": "System Cost ($/MWh)",
        "transmission_mw": "Transmission (MW)",
        "ldes_mw": "LDES (MW)",
        "vres_curtailment_mwh": "Curtailment (MWh)",
    },
)
plt.show()

# Save all paper figures
visualize_results.create_paper_figures(results, outdir="figures/paper")

# Powerpoint figures
visualize_results.set_slide_style()

fig, axes = visualize_results.plot_slide_main_panel(results)
plt.show()

fig, ax = plt.subplots()
visualize_results.plot_transmission_build(results, ax=ax)
plt.show()

fig, ax = plt.subplots()
visualize_results.plot_curtailment(results, ax=ax)
plt.show()

fig, ax = plt.subplots()
visualize_results.plot_ldes_energy(results, ax=ax)
plt.show()

fig, ax = plt.subplots(figsize=(8.5, 5))
visualize_results.plot_storage_comparison(results, ax=ax)
plt.show()

fig, ax = plt.subplots(figsize=(7.5, 6))
visualize_results.plot_ldes_vs_transmission(results, ax=ax)
plt.show()

fig, ax = plt.subplots()
visualize_results.plot_backup_capacity(results, ax=ax)
plt.show()

# Save all pp figures
visualize_results.create_slide_figures(results, outdir="figures/slides")"""
# Out:
# '\nfig, ax = plt.subplots()\nvisualize_results.plot_backup_capacity(results, ax=ax)\nplt.show()\n\nfig, ax = plt.subplots(figsize=(8.5, 4.8))\nvisualize_results.plot_storage_comparison(results, ax=ax)\nplt.show()\n\nfig, ax = plt.subplots(figsize=(7, 6))\nvisualize_results.plot_ldes_vs_transmission(results, ax=ax)\nplt.show()\n\nfig, ax = plt.subplots(figsize=(10, 5))\nvisualize_results.plot_generation_mix_bars(results, ax=ax)\nplt.show()\n\n# Optional cost figures\nif {\n    "generator_capex_total",\n    "storage_capex_total",\n    "link_capex_total",\n    "generator_opex_total",\n}.issubset(results.columns):\n    fig, ax = plt.subplots(figsize=(10, 5))\n    visualize_results.plot_cost_components(results, ax=ax)\n    plt.show()\n\nif {"total_capex", "total_opex"}.issubset(results.columns):\n    fig, ax = plt.subplots(figsize=(8.5, 4.8))\n    visualize_results.plot_capex_vs_opex(results, ax=ax)\n    plt.show()\n\nif "cost_reconstruction_error" in results.columns:\n    fig, ax = plt.s
# ...

# %%
fig, axes = visualize_results.plot_tx_vs_ldes_bar(results, use_energy=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (8, 5))
visualize_results.plot_tx_vs_storage_dual_axis(results, ax=ax)
plt.show()
